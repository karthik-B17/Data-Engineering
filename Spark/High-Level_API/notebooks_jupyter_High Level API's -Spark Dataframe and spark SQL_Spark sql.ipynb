# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://test-hadoop-cluster-m.us-central1-f.c.modern-cipher-474516-t2.internal:40861">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder\
.appName('Spark sql')\
.master('Yarn')\
.getOrCreate()
# Out:
# 25/12/29 18:02:11 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# Insert data into the table from a DataFrame
data = [
(1, "Alice", "Mumbai", "2023-01-15", True),
(2, "Bob", "Delhi", "2023-03-25", False),
(3, "Charlie", "Chennai", "2023-05-10", True)
]

columns = ["customer_id", "name", "city", "registration_date", "is_active"]

df= spark.createDataFrame(data, columns)

# %%
spark.sql('show databases').show()
# Out:
# ivysettings.xml file not found in HIVE_HOME or HIVE_CONF_DIR,/etc/hive/conf.dist/ivysettings.xml will be used
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %%
spark.sql('use default')
# Out:
# DataFrame[]

# %%
spark.sql('show tables').show()
# Out:
# +---------+-------------------+-----------+
# |namespace|          tableName|isTemporary|
# +---------+-------------------+-----------+
# |  default|customer_persistent|      false|
# +---------+-------------------+-----------+

# %%
spark. sql('''
CREATE TABLE IF NOT EXISTS customers (
customer_id INT,
name STRING,
city STRING,
registration_date STRING,
is_active BOOLEAN
) USING CSV''')
# Out:
# 25/12/29 18:23:00 WARN HiveExternalCatalog: Couldn't find corresponding Hive SerDe for data source provider CSV. Persisting data source table `spark_catalog`.`default`.`customers` into Hive metastore in Spark SQL specific format, which is NOT compatible with Hive.
# 25/12/29 18:23:00 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
# DataFrame[]

# %%
spark.sql('show tables').show()
# Out:
# +---------+-------------------+-----------+
# |namespace|          tableName|isTemporary|
# +---------+-------------------+-----------+
# |  default|customer_persistent|      false|
# |  default|          customers|      false|
# +---------+-------------------+-----------+

# %%
df.write.mode('overwrite').saveAsTable('default.customers')

# %%
spark.sql('select * from customers limit 5').show()
# Out:
# +-----------+-------+-------+-----------------+---------+
# |customer_id|   name|   city|registration_date|is_active|
# +-----------+-------+-------+-----------------+---------+
# |          1|  Alice| Mumbai|       2023-01-15|     true|
# |          2|    Bob|  Delhi|       2023-03-25|    false|
# |          3|Charlie|Chennai|       2023-05-10|     true|
# +-----------+-------+-------+-----------------+---------+

# %%
spark.sql('''
drop table customer_persistent

''')
# Out:
# DataFrame[]

# %%
# Table


# Data and the MetaData

# Data is stored in HDFS
# Metadata is on the Hive metastore


#Drop the table deleted the metadata and the hdfs data
