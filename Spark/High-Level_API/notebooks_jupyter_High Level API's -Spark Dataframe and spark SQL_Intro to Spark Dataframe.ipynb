# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://test-hadoop-cluster-m.us-central1-f.c.modern-cipher-474516-t2.internal:35075">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder\
.appName('use Spark Higher level api')\
.getOrCreate()
# Out:
# 25/12/19 09:24:44 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
df=spark.read.format('csv')\
.option('header','true')\
.option('inferSchema','true')\
.load('/tmp/1MB/customers.csv')

# %%
df
# Out:
# DataFrame[customer_id: int, name: string, city: string, state: string, country: string, registration_date: date, is_active: boolean]

# %%
df.show(5)
# Out:
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|     Pune|Maharashtra|  India|       2025-06-29|    false|
# |          1|Customer_1|Bangalore| Tamil Nadu|  India|       2025-12-07|     true|
# |          2|Customer_2|Hyderabad|    Gujarat|  India|       2025-10-27|     true|
# |          3|Customer_3|Bangalore|  Karnataka|  India|       2025-10-17|    false|
# |          4|Customer_4|Ahmedabad|  Karnataka|  India|       2025-03-14|    false|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- customer_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- registration_date: date (nullable = true)
#  |-- is_active: boolean (nullable = true)

# %%
df.createOrReplaceTempView('customers')

# %%
result =spark.sql('select city,count(*) from customers group by city')

# %%
result.show()
# Out:
# [Stage 4:>                                                          (0 + 1) / 1]
# +---------+--------+
# |     city|count(1)|
# +---------+--------+
# |    Delhi|    2200|
# |  Kolkata|    2223|
# |Hyderabad|    2242|
# |Bangalore|    2211|
# |Ahmedabad|    2198|
# |  Chennai|    2194|
# |   Mumbai|    2142|
# |     Pune|    2243|
# +---------+--------+

# %%
df_2=spark.read\
.format('csv')\
.option('header','true')\
.option('inferSchema','true')\
.load('data/Ecommerce_Customers.csv')

# %%
df_2.show()
# Out:
# +--------------------+--------------------+------------------+-------------------+------------------+------------------+--------------------+-------------------+
# |               Email|             Address|            Avatar|Avg. Session Length|       Time on App|   Time on Website|Length of Membership|Yearly Amount Spent|
# +--------------------+--------------------+------------------+-------------------+------------------+------------------+--------------------+-------------------+
# |mstephenson@ferna...|    835 Frank Tunnel|              NULL|               NULL|              NULL|              NULL|                NULL|               NULL|
# |         Wrightmouth|      MI 82180-9605"|            Violet|  34.49726772511229|12.655651149166752| 39.57766801952616|   4.082620632952961|  587.9510539684005|
# |   hduke@hotmail.com|  4547 Archer Common|              NULL|               NULL|              NULL|              NULL|                NULL|               NULL|
# ...

# %%
df_2.printSchema()
# Out:
# root
#  |-- Email: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- Avatar: string (nullable = true)
#  |-- Avg. Session Length: double (nullable = true)
#  |-- Time on App: double (nullable = true)
#  |-- Time on Website: double (nullable = true)
#  |-- Length of Membership: double (nullable = true)
#  |-- Yearly Amount Spent: double (nullable = true)

# %%
active_Customers=df_2.filter('`Yearly Amount Spent`>300').select('Avatar','Email','Yearly Amount Spent')

# %%
active_Customers
# Out:
# DataFrame[Avatar: string, Email: string, Yearly Amount Spent: double]

# %%
active_Customers.show()
# Out:
# +----------------+------------------+-------------------+
# |          Avatar|             Email|Yearly Amount Spent|
# +----------------+------------------+-------------------+
# |          Violet|       Wrightmouth|  587.9510539684005|
# |       DarkGreen|       Diazchester|  392.2049334443264|
# |          Bisque|       Cobbborough| 487.54750486747207|
# |     SaddleBrown|        Port Jason|  581.8523440352178|
# |MediumAquaMarine|   Port Jacobville|  599.4060920457634|
# |     FloralWhite|    Jeffreychester|   637.102447915074|
# |   DarkSlateBlue|        Josephbury|  521.5721747578274|
# |          Salmon|        West Debra|  570.2004089636195|
# |          Tomato|    Alexandriaport|  492.6060127179966|
# |       RoyalBlue|    Lake Shanestad| 408.64035107262754|
# |          Bisque|New Stephaniehaven|  573.4158673313865|
# |        DarkBlue|      Samanthaland| 470.45273330095546|
# |            Peru|       Phillipstad|  461.7807421962299|
# ...

# %%
from pyspark.sql.types import StructType,StructField,IntegerType,FloatType,BooleanType,StringType,DoubleType

# %%
schema = StructType([
    StructField("Email", StringType(), True),
    StructField("Address", StringType(), True),
    StructField("Avatar", StringType(), True),
    StructField("Avg. Session Length", DoubleType(), True),
    StructField("Time on App", DoubleType(), True),
    StructField("Time on Website", DoubleType(), True),
    StructField("Length of Membership", DoubleType(), True),
    StructField("Yearly Amount Spent", DoubleType(), True)
])

# %%
df_2=spark.read\
.format('csv')\
.option('header','true')\
.schema(schema)\
.load('data/Ecommerce_Customers.csv')

# %%
df_2.show()
# Out:
# +--------------------+--------------------+------------------+-------------------+------------------+------------------+--------------------+-------------------+
# |               Email|             Address|            Avatar|Avg. Session Length|       Time on App|   Time on Website|Length of Membership|Yearly Amount Spent|
# +--------------------+--------------------+------------------+-------------------+------------------+------------------+--------------------+-------------------+
# |mstephenson@ferna...|    835 Frank Tunnel|              NULL|               NULL|              NULL|              NULL|                NULL|               NULL|
# |         Wrightmouth|      MI 82180-9605"|            Violet|  34.49726772511229|12.655651149166752| 39.57766801952616|   4.082620632952961|  587.9510539684005|
# |   hduke@hotmail.com|  4547 Archer Common|              NULL|               NULL|              NULL|              NULL|                NULL|               NULL|
# ...

# %%
df_2.printSchema()
# Out:
# root
#  |-- Email: string (nullable = true)
#  |-- Address: string (nullable = true)
#  |-- Avatar: string (nullable = true)
#  |-- Avg. Session Length: double (nullable = true)
#  |-- Time on App: double (nullable = true)
#  |-- Time on Website: double (nullable = true)
#  |-- Length of Membership: double (nullable = true)
#  |-- Yearly Amount Spent: double (nullable = true)
