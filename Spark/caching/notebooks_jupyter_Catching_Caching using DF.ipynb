# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://test-hadoop-cluster-m.us-central1-f.c.modern-cipher-474516-t2.internal:41213">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder\
.appName('Cat-Usi-DF')\
.enableHiveSupport()\
.getOrCreate()
# Out:
# 26/01/01 03:22:33 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
customers_df=spark.read.option('header','true').csv('/tmp/1MB/customers.csv')

# %%
customers_df.show(5)
# Out:
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|     Pune|Maharashtra|  India|       2025-06-29|    False|
# |          1|Customer_1|Bangalore| Tamil Nadu|  India|       2025-12-07|     True|
# |          2|Customer_2|Hyderabad|    Gujarat|  India|       2025-10-27|     True|
# |          3|Customer_3|Bangalore|  Karnataka|  India|       2025-10-17|    False|
# |          4|Customer_4|Ahmedabad|  Karnataka|  India|       2025-03-14|    False|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# only showing top 5 rows

# %%
customers_df.rdd.getNumPartitions()
# Out:
# 1

# %%
customers_df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- registration_date: string (nullable = true)
#  |-- is_active: string (nullable = true)

# %%
customers_df.cache() # This behaviour will be different in different platform like azure,aws....
# Out:
# 26/01/01 03:26:51 WARN CacheManager: Asked to cache already cached data.
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
customers_df.show(3)
# Out:
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |customer_id|      name|     city|      state|country|registration_date|is_active|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# |          0|Customer_0|     Pune|Maharashtra|  India|       2025-06-29|    False|
# |          1|Customer_1|Bangalore| Tamil Nadu|  India|       2025-12-07|     True|
# |          2|Customer_2|Hyderabad|    Gujarat|  India|       2025-10-27|     True|
# +-----------+----------+---------+-----------+-------+-----------------+---------+
# only showing top 3 rows

# %%
customers_df.unpersist()
# Out:
# DataFrame[customer_id: string, name: string, city: string, state: string, country: string, registration_date: string, is_active: string]

# %%
tail_df=customers_df.orderBy('customer_id',ascending=False)

# %%
tail_df.show(3)
# Out:
# +-----------+-------------+---------+---------+-------+-----------------+---------+
# |customer_id|         name|     city|    state|country|registration_date|is_active|
# +-----------+-------------+---------+---------+-------+-----------------+---------+
# |       9999|Customer_9999|Hyderabad|Karnataka|  India|       2025-06-02|    False|
# |       9998|Customer_9998|     Pune|Telangana|  India|       2025-01-27|    False|
# |       9997|Customer_9997|Hyderabad|    Delhi|  India|       2025-06-05|     True|
# +-----------+-------------+---------+---------+-------+-----------------+---------+
# only showing top 3 rows

# %%
customers_filtered=customers_df.filter(customers_df.city=='Hyderabad').show(4)
# Out:
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |customer_id|       name|     city|      state|country|registration_date|is_active|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# |          2| Customer_2|Hyderabad|    Gujarat|  India|       2025-10-27|     True|
# |          5| Customer_5|Hyderabad|  Karnataka|  India|       2025-07-28|    False|
# |         14|Customer_14|Hyderabad| Tamil Nadu|  India|       2025-02-07|    False|
# |         17|Customer_17|Hyderabad|West Bengal|  India|       2025-08-21|    False|
# +-----------+-----------+---------+-----------+-------+-----------------+---------+
# only showing top 4 rows

# %%
spark.stop()
